# %%
# esc 跳出cell
# enter進入cell   
# 往下新增 B
# 往上新增 A
# X刪除cell
# alt 搭配方向鍵移動程式碼
# ctrl + d 一次修改多個變數
# alt + shift + 方向鍵 複製某一行程式碼 
# ctrl + x 刪除整列
# 快捷打開關閉 終端機 ctrl + `
# ctrl + b 開關側邊攔
# ctrl + tab 切換檔案
# ctrl + w 關閉檔案
x =10 
print(x)
# Out:
# 10
