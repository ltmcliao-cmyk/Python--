# %%
# 類別名稱
# 類別屬性 (Class Attribute)

# %%
class Car:
    wheels = 4
    def __init__(self,brand,model):
        self.bd = brand
        self.md = model
        self.door = 4

    def display_info(self):
        return f"The {self.bd} {self.md} has {Car.wheels} wheels."
    

car1 = Car("alhpaRomeo","model1")
print(Car.wheels)
print(car1.wheels)
# Out:
# 4
# 4

# %%
# 類別名稱
# 類別屬性 (Class Attribute)

# 方法 (Method)
