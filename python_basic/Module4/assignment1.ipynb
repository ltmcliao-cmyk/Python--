# %% [markdown]
# 情境：模擬一個簡單的排隊系統。
# 輸入：queue = ["John", "Amy", "Kevin"]
# 要求：
#     1. 新的客人 "Sandy" 來排隊（加到最後）。
#     2. "John" 完成服務離開了（移除第一個）。
#     3. 插隊：將 VIP 客人 "Boss" 放到隊伍最前面。
#
# 預期輸出：目前隊伍: ['Boss', 'Amy', 'Kevin', 'Sandy']
