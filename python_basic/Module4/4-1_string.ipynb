# %% [markdown]
# |string方法| 功能 |
# |:---:|:---:|
# | | 替換字串 |
# | | 去除兩側空格 |
# | | 字串小寫變大寫 |
# | | 字串大寫變小寫 |

# %%
# 字串變數初始化

# %%
# 替換字串
'''

將 string 中的 str1 替換成 str2
'''
name = "a"
new_name = name.replace("a","b")
print(new_name)
# Out:
# b

# %%
# 去除兩側空格
'''
去除字串 string 左、右兩邊的空格
'''
data = "_A_"
new_data = data.strip("_")
print(data)
print(new_data)


new1_data = data.lstrip("_")
print(new1_data)
# Out:
# _A_
# A
# A_

# %%
# 字串小寫變大寫
'''

將字串 string 裡的字母全部改成小寫
'''



'''

將字串 string 裡的字母全部改成大寫
'''

# %%
# 字串分割成 list
greeting = "hello world! hello John"
greeting_new = greeting.replace(" ",",")
print(greeting_new)
greeting_lst = greeting_new.split(",")
print(greeting_lst)
# Out:
# hello,world!,hello,John
# ['hello', 'world!', 'hello', 'John']
