# %% [markdown]
# ##### try...except...

# %%
# 可以連續定義數個例外處理機制
# 最符合的例外事件類別會先拋出

# %%
try:
    x = 100
    print(y)
    print(x) #不會被執行
except Exception as e: #會把當初error的message打包在e，所以才說囊括大部分錯誤
    print(f"程式發生錯誤 {e}")
# Out:
# 程式發生錯誤 name 'y' is not defined

# %%
x = -1

if x < 0 :
    raise Exception("你他媽的不能小於0")

print(x)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 x = -1
#       3 if x < 0 :
# ----> 4     raise Exception("你他媽的不能小於0")
#       6 print(x)
#
# Exception: 你他媽的不能小於0

# %%
lst = []

def only_str(x):
    if type(x) != "String":
        raise TypeError("你他媽只能塞str")
    
only_str(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       4     if type(x) != "String":
#       5         raise TypeError("你他媽只能塞str")
# ----> 7 only_str(lst)
#
# Cell In[6], line 5, in only_str(x)
#       3 def only_str(x):
#       4     if type(x) != "String":
# ----> 5         raise TypeError("你他媽只能塞str")
#
# TypeError: 你他媽只能塞str

# %%
# 多層例外處理:

# %% [markdown]
# ##### try...except...else...finally

# %%
# 如果沒有錯誤，就會執行 else 程式區塊
# finally 程式區塊是無論有無錯誤，都會執行
